# %%
# ==========================================
# HYBRID ANOMALY DETECTION (COMPETITION READY)
# CNN Autoencoder + Isolation Forest
# ==========================================
#
# The implementation now lives in src/pipelines/run_hybrid.py (deduplicated
# from this notebook's two previous copies of the same ~200-line pipeline).
# This cell just runs it and keeps the metrics available for inspection.

import os
import sys

PROJECT_ROOT = os.path.abspath("..")
sys.path.append(PROJECT_ROOT)
os.chdir(PROJECT_ROOT)  # pipeline paths (data/, outputs/) are repo-root relative

from src.pipelines.run_hybrid import main

metrics = main()
# Out:
# Epoch 1: 0.151196
# Epoch 2: 0.043259
# Epoch 3: 0.034407
# Epoch 4: 0.031901
# Epoch 5: 0.029203
# Epoch 6: 0.027271
# Epoch 7: 0.024771
# Epoch 8: 0.024116
# Epoch 9: 0.023419
# Epoch 10: 0.022056
# Best F1: 0.509422487750049
# Best threshold: 0.08509332690862001
# Saved: ../outputs/hybrid_predictions.csv
# Shape: (316024, 3)
# DONE ✔

# %%
import json

print(json.dumps(metrics["hybrid"], indent=2))
# Out:
# Precision: 0.40298148593411875
# Recall: 0.6922759190417183
# F1 Score: 0.5094224924012158
